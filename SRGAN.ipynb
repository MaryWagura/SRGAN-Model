# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryWagura/SRGAN-Model/blob/main/SRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PHASE 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Copy the unzipped SRGAN-PyTorch folder into Colab's local space
# !cp -r "/content/drive/MyDrive/SRGAN_PROJECT/SRGAN-PyTorch" "/content/"

# 2. Unzip the SAR dataset (with the corrected hyphen!)
# !unzip "/content/drive/MyDrive/SRGAN_PROJECT/SAR-SuperResolution.zip" -d "/content/data/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001448.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001449.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001450.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001451.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001452.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001453.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001454.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001455.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001456.png
#   inflating: /content/data/SAR-SuperResolution/data/SAR_Dataset/train_LR/patch_001457.png
# ...

# %%
# %cd /content/SRGAN-PyTorch
# !pip install -r requirements.txt
# Out:
# /content/SRGAN-PyTorch
# ...

# %%
# !python train_net.py --config_path ./configs/train/SRResNet_x4-ImageNet.yaml
# Out:
# 2026-03-15 13:55:50.387955: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773582950.424379    9577 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773582950.435717    9577 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773582950.463580    9577 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !cp -r /content/SRGAN-PyTorch/samples /content/drive/MyDrive/SRGAN_PROJECT/
